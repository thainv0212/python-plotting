# %% [markdown]
# # Plotting with Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.style.available
# Out:
# ['seaborn-deep',
#  'seaborn-pastel',
#  'seaborn',
#  'seaborn-ticks',
#  'seaborn-paper',
#  'bmh',
#  'Solarize_Light2',
#  'seaborn-whitegrid',
#  'seaborn-bright',
#  'fast',
#  'seaborn-white',
#  'ggplot',
#  'seaborn-darkgrid',
#  'grayscale',
#  'seaborn-talk',
#  'seaborn-poster',
#  'seaborn-notebook',
#  'fivethirtyeight',
#  'classic',
#  'seaborn-dark-palette',
#  'dark_background',
#  'seaborn-dark',
#  '_classic_test',
#  'seaborn-muted',
#  'seaborn-colorblind']

# %%
plt.style.use('seaborn')

# %% [markdown]
# # Dataframe.plot

# %%
np.random.seed(1)
df = pd.DataFrame({'A': np.random.randn(365).cumsum(0),
                  'B': np.random.randn(365).cumsum(0) + 20,
                  'C': np.random.randn(365).cumsum(0) - 20},
                 index=pd.date_range('1/1/2017', periods=365))
df
# Out:
#                     A          B          C
# 2017-01-01   1.624345  20.727813 -19.033779
# 2017-01-02   1.012589  20.515074 -18.307862
# 2017-01-03   0.484417  17.217466 -14.986784
# 2017-01-04  -0.588551  20.584647 -15.587009
# 2017-01-05   0.276856  20.324274 -15.966526
# 2017-01-06  -2.024682  20.021863 -16.981330
# 2017-01-07  -0.279871  19.531326 -16.545344
# 2017-01-08  -1.041078  20.853281 -17.232831
# 2017-01-09  -0.722039  19.586971 -19.931193
# 2017-01-10  -0.971409  21.834718 -21.144531
# 2017-01-11   0.490699  20.564383 -21.072279
# 2017-01-12  -1.569442  22.137828 -20.062492
# 2017-01-13  -1.891859  19.214466 -21.619433
# 2017-01-14  -2.275913  18.244074 -22.231876
# 2017-01-15  -1.142144  20.714790 -22.371227
# 2017-01-16  -2.242035  20.852704 -23.099765
# 2017-01-17  -2.414463  20.035360 -22.568601
# 2017-01-18  -3.292322  18.461207 -22.564600
# 2017-01-19  -3.250108  19.552105 -22.243334
# 2017-01-20  -2.667293  20.617986 -22.968549
# 2017-01-21  -3.767912  19.815824 -21.432013
# 2017-01-22  -2.623188  19.884015 -21.432388
# 2017-01-23  -1.721597  19.824541 -20.138838
# 2017-01-24  -1.219103  19.066085 -20.577836
# 2017-01-25  -0.318247  19.466980 -19.987797
# 2017-01-26  -1.001975  18.573445 -20.667180
# 2017-01-27  -1.124865  21.767960 -21.618090
# 2017-01-28  -2.060635  19.524627 -22.322440
# 2017-01-29  -2.328523  20.477610 -22.368307
# 2017-01-30  -1.798167  18.978114 -22.587040
# ...               ...        ...        ...
# 2017-12-02  29.704621  19.209200 -14.632707
# 2017-12-03  27.667420  21.223722 -14.618259
# 2017-12-04  25.724831  19.940632 -16.097839
# 2017-12-05  23.218390  21.448989 -16.338539
# 2017-12-06  21.104226  19.522419 -17.194211
# 2017-12-07  20.692587  20.026000 -19.242411
# 2017-12-08  21.971115  18.651304 -18.758527
# 2017-12-09  21.528886  21.302536 -17.199839
# 2017-12-10  21.852413  19.637388 -14.830109
# 2017-12-11  21.742422  18.514844 -13.267690
# 2017-12-12  21.750971  19.407539 -14.138491
# 2017-12-13  21.582772  17.695092 -12.963246
# 2017-12-14  21.408591  19.968183 -11.843347
# 2017-12-15  21.869756  20.112488 -13.831177
# 2017-12-16  20.693773  20.288078 -12.969888
# 2017-12-17  21.703900  21.498108 -12.342711
# 2017-12-18  22.623918  19.699024 -12.179903
# 2017-12-19  22.428861  20.807456 -11.891286
# 2017-12-20  23.234254  20.312239 -11.832979
# 2017-12-21  22.532910  19.806678 -10.201043
# 2017-12-22  21.995687  17.923198 -10.602832
# 2017-12-23  22.151950  20.947501 -10.802771
# 2017-12-24  21.961729  19.496026 -10.795382
# 2017-12-25  21.512991  20.017956 -10.519718
# 2017-12-26  20.840543  18.729539 -12.282968
# 2017-12-27  20.283049  20.282996 -10.894994
# 2017-12-28  21.222217  20.108031 -10.668794
# 2017-12-29  19.278894  20.029418 -10.099670
# 2017-12-30  19.631388  19.865207  -9.902354
# 2017-12-31  19.394951  21.049218 -10.088795
#
# [365 rows x 3 columns]

# %%
df.plot();

# %%
df.plot('A', 'B', kind='scatter')

# %%
df.plot.scatter('A', 'C', c='B', s=df['B'], colormap='viridis')

# %%
ax = df.plot.scatter('A', 'C', c='B', s=df['B'], colormap='viridis')
ax.set_aspect('equal')

# %%
df.plot.box()

# %%
df.plot.hist(alpha=0.7)

# %%
df.plot.kde()

# %% [markdown]
# # Seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %%
np.random.seed(1234)

v1 = pd.Series(np.random.normal(0,10,1000), name='v1')
v2 = pd.Series(2 * v1 + np.random.normal(60,15, 1000), name='v2')

# %%
plt.figure()
plt.hist(v1, alpha=0.7, bins=np.arange(-50, 150, 5), label='v1')
plt.hist(v2, alpha=0.7, bins=np.arange(-50, 150, 5), label='v2')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist([v1, v2], histtype='barstacked', normed=True);
v3 = np.concatenate((v1, v2))
sns.kdeplot(v3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.distplot(v3, hist_kws={'color': 'Teal'}, kde_kws={'color':'Navy'})
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.jointplot(v1, v2, alpha=0.4)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
grid = sns.jointplot(v1, v2, alpha=0.4);
grid.ax_joint.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.set_style('white')
sns.jointplot(v1,v2, kind='kde', space=0)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
sns.pairplot(iris, hue='Name', diag_kind='kde')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(12,8))
plt.subplot(121)
sns.swarmplot('Name', 'PetalLength', data=iris)
plt.subplot(122)
sns.violinplot('Name', 'PetalLength', data=iris)
# Out:
# <img src="data:image/png;base64,..." width="1200">
